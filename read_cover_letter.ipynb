# %%
from transformers import pipeline

# Step 1: Load NER model for extracting names
ner_pipeline = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english")

# Example Cover Letter
cover_letter = """
Dear Hiring Manager,

My name is Jane Doe, and I am excited to apply for the Software Engineer position. I have strong skills in Python, machine learning, and data analysis. My objective is to leverage my expertise to solve challenging problems and contribute to innovative projects at your company.

Sincerely,
Jane Doe
"""

# Step 2: Extract Named Entities (e.g., Name)
entities = ner_pipeline(cover_letter)
name = [entity["word"] for entity in entities if entity["entity"] == "B-PER"]

# Step 3: Extract Skills and Objectives
skills_keywords = ["Python", "machine learning", "data analysis"]
objective_keywords = ["objective", "goal", "aspire", "aim"]

# Extract Skills
skills = [skill for skill in skills_keywords if skill.lower() in cover_letter.lower()]

# Extract Objective (basic heuristic)
objective_sentence = next(
    (sentence for sentence in cover_letter.split(".") if any(word in sentence.lower() for word in objective_keywords)), None
)

# Step 4: Display Results
print("Extracted Name:", name)
print("Extracted Skills:", skills)
print("Extracted Objective:", objective_sentence.strip() if objective_sentence else "Not Found")
# Out:
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Device set to use mps:0
# Extracted Name: []
# ...
